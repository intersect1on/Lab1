# %%
# !pip install networkx
# !pip install matplotlib
# !pip install tqdm
# !pip install pandas
# !pip install numpy
# !pip install graphviz
# !pip install scikit-learn

# %%
import random
import networkx as nx
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from itertools import combinations, groupby

from networkx.algorithms import tree
from networkx.algorithms import bellman_ford_predecessor_and_distance
from networkx.algorithms import floyd_warshall_predecessor_and_distance

import numpy.typing as npt

# %% [markdown]
# # **Кальмук Ярополк, Гуцуляк Олег**
# ### Для лабораторної роботи з дискретної математики потрібно було:
# ####  1. Розробити та дослідити роботи алгоритмів - Прима або Крускала та Белмана-Форда або Флойда-Воршалла на графах з різною кількістю вершин та ребер між ними. Порівняти їхню реалізацію з вбудованими, проілюструвати графік часу роботи.
# #### 2. Імплементувати дерево рішень, за допомогою якого передбачувати результат з уже наявних даних.
# ### Отже, як алгоритми ми обрали алгоритм Крускала та алгоритм Флойда-Воршалла, реалізацію яких можете побачити знизу.

# %% [markdown]
# # Task 1. Algorithm's analysis

# %% [markdown]
# ## Generating graph

# %%
# You can use this function to generate a random graph with 'num_of_nodes' nodes
# and 'completeness' probability of an edge between any two nodes
# If 'directed' is True, the graph will be directed
# If 'draw' is True, the graph will be drawn
def gnp_random_connected_graph(num_of_nodes: int,
                               completeness: int,
                               directed: bool = False,
                               draw: bool = False):
    """
    Generates a random graph, similarly to an Erdős-Rényi 
    graph, but enforcing that the resulting graph is conneted (in case of undirected graphs)
    """

    
    if directed:
        G = nx.DiGraph()
    else:
        G = nx.Graph()
    edges = combinations(range(num_of_nodes), 2)
    G.add_nodes_from(range(num_of_nodes))
    
    for _, node_edges in groupby(edges, key = lambda x: x[0]):
        node_edges = list(node_edges)
        random_edge = random.choice(node_edges)
        if random.random() < 0.5:
            random_edge = random_edge[::-1]
        G.add_edge(*random_edge)
        for e in node_edges:
            if random.random() < completeness:
                G.add_edge(*e)
                
    for (u,v,w) in G.edges(data=True):
        w['weight'] = random.randint(-5, 20)
                
    if draw: 
        plt.figure(figsize=(10,6))
        if directed:
            # draw with edge weights
            pos = nx.arf_layout(G)
            nx.draw(G,pos, node_color='lightblue', 
                    with_labels=True,
                    node_size=500, 
                    arrowsize=20, 
                    arrows=True)
            labels = nx.get_edge_attributes(G,'weight')
            nx.draw_networkx_edge_labels(G, pos,edge_labels=labels)
            
        else:
            nx.draw(G, node_color='lightblue', 
                with_labels=True, 
                node_size=500)
        
    return G

# %%
G = gnp_random_connected_graph(10, 0.3, False, True)

# %% [markdown]
# ## Subtask 1.1

# %% [markdown]
# ### Kruskal's algorithm

# %%
mstk = tree.minimum_spanning_tree(G, algorithm="kruskal")

# %%
nx.draw(mstk, node_color='lightblue', 
        with_labels=True, 
        node_size=500)

# %%
mstk.edges(), len(mstk.edges())

# %%
def kruskal_algorithm(G: nx.Graph):
    """
    Uses kruskal`s algorithm to find frame of the graph
    with minimum weight possible
    """
    edges = list(G.edges(data=True))
    nodes = list(G.nodes())
    visited = [{node} for node in nodes]
    result = []
    edges = sorted(edges, key = lambda x: x[2]["weight"])
    for edge in edges:
        flag = True
        if len(visited) == 1:
            break

        for vertice_set in visited:
            if {edge[0], edge[1]}.issubset(vertice_set):
                flag = False
                break
            if edge[0] in vertice_set:
                set_1 = vertice_set
                set_1_idx = visited.index(set_1)
            elif edge[1] in vertice_set:
                set_2 = vertice_set

        if not flag:
            continue
        visited[set_1_idx].update(set_2)
        visited.remove(set_2)
        result.append(edge)
    return result

print(kruskal_algorithm(G))
# Out:
# [(2, 7, {'weight': -5}), (0, 2, {'weight': -4}), (3, 9, {'weight': -3}), (7, 8, {'weight': -3}), (1, 5, {'weight': -1}), (1, 4, {'weight': 0}), (0, 9, {'weight': 1}), (2, 6, {'weight': 6}), (4, 6, {'weight': 8})]

# %% [markdown]
# ### Prim's algorithm

# %%
mstp = tree.minimum_spanning_tree(G, algorithm="prim")

# %%
nx.draw(mstp, node_color='lightblue', 
        with_labels=True, 
        node_size=500)

# %%
mstp.edges(), len(mstp.edges())

# %% [markdown]
# *put your code below* (delete this)

# %% [markdown]
# ## Subtask 1.2

# %%
G = gnp_random_connected_graph(10, 0.5, True, True)

# %% [markdown]
# ### Bellman-Ford algorithm

# %%
# pred is a dictionary of predecessors, dist is a dictionary of distances
try:
    pred, dist = bellman_ford_predecessor_and_distance(G, 0)
    for k, v in dist.items():
        print(f"Distance to {k}:", v)
except:
    print("Negative cycle detected")

# %% [markdown]
# *put your code below* (delete this)

# %% [markdown]
# ### Floyd-Warshall algorithm

# %%
# pred is a dictionary of predecessors, dist is a dictionary of distances dictionaries
try:
    pred, dist = floyd_warshall_predecessor_and_distance(G)
    for i in dist:
        if dist[i][i] < 0:
            raise Exception()
    for k, v in dist.items():
        print(f"Distances with {k} source:", dict(v))
except:
    print("Negative cycle detected")

# %%
def floyd_warshall_algorithm(G: nx.Graph) -> dict:
    """
    Computes the shortest paths for every node in graph G.
    If a negative cycle is detected raises an exception.

    :param G: nx.Graph, The random graph.
    :returns: dict, A dictionary of distances.
    """
    nodes = list(G.nodes())
    dist = {i: {j: float('inf') for j in nodes} for i in nodes}

    for i in nodes:
        dist[i][i] = 0

    for u, v, data in G.edges(data=True):
        weight = data['weight']
        dist[u][v] = weight

        if not G.is_directed():
            dist[v][u] = weight

    for k in nodes:
        for i in nodes:
            for j in nodes:
                dist[i][j] = min(dist[i][k] + dist[k][j], dist[i][j])

    for i in nodes:
        if dist[i][i] < 0:
            raise Exception()

    return dist

# %%
try:
    dist = floyd_warshall_algorithm(G)
    for k, v in dist.items():
        print(f"Distances with {k} source:", dict(v))
except:
    print("Negative cycle detected")
# Out:
# Negative cycle detected

# %% [markdown]
# ---

# %% [markdown]
# ## Some useful explanations
# ### How to get list of edges for your algorithm

# %%
edges = list(G.edges(data=True)) # by default G.edges are EdgesView class

# %%
edges[:5]

# %% [markdown]
# ### To get edges with weights

# %%
edges = list(G.edges(data=True))

# %%
edges[:5]

# %%
nodes = list(G.nodes())
print(nodes)

# %% [markdown]
# ## Example on time measuring
#
# Read more on this: https://realpython.com/python-timer/
#
# Recall that you should measure times for 5, 10, 20, 50, 100, 200, 500 nodes 1000 times (and take mean of time taken for each node amount).
#
# Then you should build the plot for two algorithms (x - data size, y - mean time of execution).

# %%
import time
from tqdm import tqdm

# %% [markdown]
# ## Порівняння результатів алгоритму Крускала власної розробки з вбудованим алгоритмом

# %%
x_axis = []
y_axis_our = []
y_axis_built_in = []
for vertices in [5, 10, 20, 50, 100, 200, 500]:
    NUM_OF_ITERATIONS = 1000
    time_taken_our = 0
    time_taken_built_in = 0
    for i in tqdm(range(NUM_OF_ITERATIONS)):
        
        G = gnp_random_connected_graph(vertices, 0.4, False)
        
        start_our = time.time()
        kruskal_algorithm(G)
        end_our = time.time()
        
        start_built_in = time.time()
        tree.minimum_spanning_tree(G, algorithm="kruskal")
        end_built_in = time.time()
        
        time_taken_our += end_our - start_our
        time_taken_built_in += end_built_in - start_built_in

    our_mean_time = time_taken_our / NUM_OF_ITERATIONS
    built_in_mean_time = time_taken_built_in / NUM_OF_ITERATIONS

    x_axis.append(vertices)
    y_axis_our.append(our_mean_time)
    y_axis_built_in.append(built_in_mean_time)
plt.plot(x_axis, y_axis_our, label = "Our algorithm")
plt.plot(x_axis, y_axis_built_in, label = "Built in algorithm")
plt.legend()
plt.show()
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 20241.31it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 9585.07it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 3283.86it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 662.92it/s]
# 100%|██████████| 1000/1000 [00:05<00:00, 181.84it/s]
# 100%|██████████| 1000/1000 [00:26<00:00, 38.26it/s]
# 100%|██████████| 1000/1000 [05:39<00:00,  2.94it/s]

# %% [markdown]
# #### Ми проаналізували алгоритми на неорієнтованих графах з вершинами 5, 10, 20, 50, 100, 200, 500 з імовірністю ребра між кожними двома вершинами -0.4 . Бачимо графік, координата x якого - кількість вершин у графі, а y - час (у с) двох алгоритмів: синій колір - наш алгоритм, оранжевий - вбудований. За графіком можем побачити, що чим більше вершин буде у графі, тим швидший буде вбудований алгоритм за наш. Це ми можемо припустити, виходячи з того, що на 500 вершинах уповільнення нашої розробки більше. Щодо кращого показника нашого алгоритму на 200 вершинах - ми вважаємо це похибкою, меншою за 0.001 с.

# %% [markdown]
# ## Порівняння результатів алгоритму Флойда-Воршалла власної розробки з вбудованим алгоритмом

# %%
x_axis = []
y_axis_our = []
y_axis_built_in = []
for vertices in [5, 10, 20, 50, 100]:
    NUM_OF_ITERATIONS = 1000
    time_taken_our = 0
    time_taken_built_in = 0
    for i in tqdm(range(NUM_OF_ITERATIONS)):
        G = gnp_random_connected_graph(vertices, 0.01, True, False)

        start_our = time.time()
        try:
            dist = floyd_warshall_algorithm(G)
        except:
            pass
        end_our = time.time()
        
        start_built_in = time.time()
        try:
            pred, dist = floyd_warshall_predecessor_and_distance(G)
            for i in dist:
                if dist[i][i] < 0:
                    raise Exception()
        except:
            pass
        end_built_in = time.time()
        
        time_taken_our += end_our - start_our
        time_taken_built_in += end_built_in - start_built_in

    our_mean_time = time_taken_our / NUM_OF_ITERATIONS
    built_in_mean_time = time_taken_built_in / NUM_OF_ITERATIONS

    x_axis.append(vertices)
    y_axis_our.append(our_mean_time)
    y_axis_built_in.append(built_in_mean_time)
plt.plot(x_axis, y_axis_our, label = "Our algorithm")
plt.plot(x_axis, y_axis_built_in, label = "Built in algorithm")
plt.legend()
plt.show()
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 17079.45it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 5440.34it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 894.70it/s]
# 100%|██████████| 1000/1000 [00:15<00:00, 66.16it/s]
# 100%|██████████| 1000/1000 [01:57<00:00,  8.52it/s]

# %% [markdown]
# #### Бачимо схожий графік з одинаковими вісями x i y, але через велику складність алгоритму (On^3) було обрано проводити експерименти на орієнтованому графі з 5, 10, 20, 50 та 100 вершинами з імовірністю між двома вершинами - 0.01 (це задля зменшення імовірності циклів з від'ємною вагою у графах). Як можем спостерігати, уже на 50 вершинах наш алгоритм програє у часі, і зростає цей програш у швидкому темпі при збільшенні вершин у графі.

# %% [markdown]
# ## Task 2. Decision Tree Classifier

# %%
# scikit-learn package
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.model_selection import train_test_split

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# ### General idea
#
# #### You are expected to write a quite simple, yet good core logic of decision tree classifier class. Additionaly, you need to test your results and write down a report on what you've done, which principles used and explain the general process.
#
# #### Hopefully, you have already learned what is decision tree classifier and how it work. For better understanding, and in case if something is still unclear for you, here are some useful links on basics of DTC:
# - https://www.youtube.com/watch?v=ZVR2Way4nwQ
# - https://towardsdatascience.com/decision-tree-classifier-explained-a-visual-guide-with-code-examples-for-beginners-7c863f06a71e
# - https://towardsdatascience.com/decision-tree-from-scratch-in-python-46e99dfea775
# - https://www.kaggle.com/code/prashant111/decision-tree-classifier-tutorial
# - https://towardsdatascience.com/decision-tree-classifier-explained-in-real-life-picking-a-vacation-destination-6226b2b6057
#
# #### Also, for those interested to learn more about machine learning and particulary Desicion Trees - here is a great course on Coursera (you may be interested in the whole course or just this particular week):
# - https://www.coursera.org/learn/advanced-learning-algorithms/home/week/4

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# ### Dataset
# #### You can use Iris dataset for this task. It is a very popular dataset for machine learning and data science. It contains 150 samples of 3 different species of Iris flowers (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters.
# Read more on this: https://scikit-learn.org/stable/auto_examples/datasets/plot_iris_dataset.html
# https://en.wikipedia.org/wiki/Iris_flower_data_set
# #### However, using more interesting and intricate datasets is much appreciated. You can use any dataset you want, but it should be a classification one. For example you can use breast cancer or wine datasets, which are also available in sklearn.datasets. Or you can use any other dataset you find interesting.
# P.S. In case you are not sure if your dataset is suitable, feel free to ask assistants :).

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %%
# Load dataset
iris = load_iris()
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
iris.data.shape
# Out:
# (150, 4)

# %% [markdown]
# This means that we have 150 entries (samples, infos about a flower). The columns being: Sepal Length, Sepal Width, Petal Length and Petal Width(features). Let's look at first two entries:

# %%
iris.data[0:2]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2]])

# %% [markdown]
# ### To undestand data little bit better, let's plot some features

# %%
X = iris.data[:, :2]  # we only take the first two features.
y = iris.target

plt.figure(2, figsize=(8, 6))
plt.clf()

# Plot the training points
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Set1, edgecolor="k")
plt.xlabel("Sepal length")
plt.ylabel("Sepal width")
# Out:
# Text(0, 0.5, 'Sepal width')

# %% [markdown]
# From this we can clearly see, that even basing on those two parameters, we can clearly divide (classify) out data into several groups. For this, we will use decision tree classifier: https://scikit-learn.org/stable/modules/tree.html#tree
#
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ### Example of usage
#
#
# **Decision Trees (DTs) are a non-parametric supervised learning method used for classification and regression**. The goal is to create a model that predicts the value of a target variable by learning simple decision rules inferred from the data features. A tree can be seen as a piecewise constant approximation.

# %%
clf = DecisionTreeClassifier()

X, y = iris.data, iris.target
X.shape, y.shape
# Out:
# ((150, 4), (150,))

# %% [markdown]
# ### Train / test split
#
# We train our model using training dataset and evaluate its performance basing on the test dataset. Reason to use two separate datasets is that our model learns its parameters from data, thus test set allows us to check its possibilities on completely new data.

# %%
X, X_test, y, y_test = train_test_split(X, y, test_size= 0.20)
X_test.shape, y_test.shape
# Out:
# ((30, 4), (30,))

# %% [markdown]
# ### Model learning
#
# It learns its parameters (where it should split data and for what threshold value) basing on the training dataset. It is done by minimizing some cost function (e.g. Gini impurity or entropy).

# %%
clf = clf.fit(X, y)

# %% [markdown]
# ### Visualization of produced tree
#
# You do not need to understand this piece of code :)

# %%
import graphviz 
dot_data = tree.export_graphviz(clf, out_file=None) 
graph = graphviz.Source(dot_data) 
graph.render("iris")
# Out:
# 'iris.pdf'

# %%
dot_data = tree.export_graphviz(clf, out_file=None, 
                     feature_names=iris.feature_names,  
                     class_names=iris.target_names,  
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(dot_data)  
graph

# %% [markdown]
# ### Prediction step
#
# Now we can use our model to predict which type has a flower, basing on its parameters.
#
# This is conducted basically via traversing the tree that you can see above.

# %%
predictions = clf.predict(X_test)

# %% [markdown]
# ### We can also measure the accuracy of our model

# %%
sum(predictions == y_test) / len(y_test)
# Out:
# np.float64(0.8333333333333334)

# %% [markdown]
# To get clearer intuition about predicion, let's look at those X, that should be labeled to some flower

# %%
y_test
# Out:
# array([1, 1, 0, 1, 2, 2, 2, 1, 1, 2, 0, 1, 0, 0, 1, 1, 0, 1, 1, 0, 2, 0,
#        0, 2, 0, 1, 0, 2, 2, 2])

# %% [markdown]
# Here you can traverse the tree above by yourself and make sure that prediction works

# %%
X_test[1]
# Out:
# array([6.1, 3. , 4.6, 1.4])

# %%
clf.predict([X_test[1]])
# Out:
# array([1])

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# ### Finally, it is your turn to write such classifier by yourself!
#
# ####  Gini impurity
#
# Decision trees use the concept of Gini impurity to describe how “pure” a node is. A node is pure (G = 0) if all its samples belong to the same class, while a node with many samples from many different classes will have a Gini closer to 1.
#
# $G = 1 - \sum_{k=1}^{n}p_{k}^2$
#
# For example, if a node contains five samples, with two belonging to the first class (first flower), two of class 2, one of class 3 and none of class 4, then
#
# $G = 1 - (\frac{2}{5})^2 - (\frac{2}{5})^2 - (\frac{1}{5})^2 = 0.64$
#
# #### Remarks
# - We recommend using additional functions in `DecisionTreeClassifier` class, to make the implementation process easier.
# - [use this hint](https://arc.net/l/quote/pqvyjqei)

# %%
class Node:
    def __init__(self, X: npt.NDArray, y: npt.NDArray, num_classes: int):
        """
        :param X: numpy array of form [[feature1, feature2, ...], ...].
        :param y: numpy array of class labels [class1, class2, ...].
        :param num_classes: Total number of classes in the dataset.
        """
        self.X = X
        self.y = y
        self.feature_index = None
        self.threshold = None
        self.left = None
        self.right = None
        self.value = np.argmax(np.bincount(y, minlength=num_classes))
        self.probabilities = ((np.bincount(y, minlength=num_classes) + 1) / (len(y) + num_classes))

# %%
class DecisionTreeClassifier:
    def __init__(self, max_depth: int) -> None:
        """
        Initializes the Decision Tree Classifier.

        :param max_depth: Maximum depth of the decision tree.
        """
        self.max_depth = max_depth
        self.tree = None
        self.number_of_classes = None

    def gini(self, y: npt.NDArray) -> float:
        """
        Calculates the Gini impurity.

        :param y: numpy array of class labels.
        """
        m = len(y)

        if m == 0:
            return 0

        return 1 - np.sum((np.bincount(y) / m) ** 2)

    def best_split(self, X: npt.NDArray, y: npt.NDArray) -> tuple:
        """
        Finds the best feature and threshold to split the data.

        :param X: numpy array of form.
        :param y: numpy array of class labels.
        :returns: tuple, containing:
            best_idx: The index of the best feature to split on.
            best_thr: The threshold value for the best split.
        """
        n_samples, n_features = X.shape
        best_idx = None
        best_thr = None
        best_gini = float('inf')

        for idx in range(n_features):
            thresholds = np.unique(X[:, idx])

            for thr in thresholds:
                left_mask = X[:, idx] <= thr
                right_mask = X[:, idx] > thr

                if np.sum(left_mask) == 0 or np.sum(right_mask) == 0:
                    continue

                gini_left = self.gini(y[left_mask])
                gini_right = self.gini(y[right_mask])
                weighted_gini = ((np.sum(left_mask) * gini_left + 
                                  np.sum(right_mask) * gini_right) / n_samples)

                if weighted_gini < best_gini:
                    best_gini = weighted_gini
                    best_idx = idx
                    best_thr = thr

        return best_idx, best_thr

    def build_tree(self, X: npt.NDArray, y: npt.NDArray, depth: int) -> Node:
        """
        Recursively builds the decision tree.

        :param X: numpy array of form.
        :param y: numpy array of class labels.
        :param depth: Current depth in the tree.
        :return: Node representing the root of this subtree.
        """
        node = Node(X, y, self.number_of_classes)

        if depth >= self.max_depth or len(y) < 2 or self.gini(y) == 0:
            return node

        best_idx, best_thr = self.best_split(X, y)

        if best_idx is None:
            return node

        node.feature_index = best_idx
        node.threshold = best_thr
        left_mask = X[:, best_idx] <= best_thr
        right_mask = X[:, best_idx] > best_thr
        node.left = self.build_tree(X[left_mask], y[left_mask], depth + 1)
        node.right = self.build_tree(X[right_mask], y[right_mask], depth + 1)

        return node

    def fit(self, X: npt.NDArray, y: npt.NDArray) -> None:
        """
        Builds the decision tree classifier from the training data.

        :param X: numpy array of form.
        :param y: numpy array of class labels.
        """
        self.number_of_classes = np.unique(y).size
        self.tree = self.build_tree(X, y, depth=0)

    def predict_sample(self, X: npt.NDArray, node: Node) -> int:
        """
        Recursively predicts the class label for a single sample.

        :param X: numpy array of form.
        """
        if node.feature_index is None:
            return node.value

        if X[node.feature_index] <= node.threshold:
            return self.predict_sample(X, node.left)
        else:
            return self.predict_sample(X, node.right)

    def predict(self, test: npt.NDArray) -> list:
        """
        Predict the class labels for a set of samples.

        :param test: Test feature matrix.
        :return: List of predicted class labels.
        """
        return [self.predict_sample(X, self.tree) for X in test]

# %%
def evaluate(model: DecisionTreeClassifier, X_test: npt.NDArray, y_test: list) -> float:
    """
    Evaluate the model on the test set.

    :param model: Trained DecisionTreeClassifier instance.
    :param X_test: Test feature matrix.
    :param y_test: Labels for the test set.
    :return: Accuracy.
    """
    predictions = model.predict(X_test)
    accuracy = np.mean(np.array(predictions) == np.array(y_test))

    return accuracy

# %%
def print_tree(node: Node, depth: int = 0) -> None:
    """
    Recursively print the tree with class probabilities.

    :param node: Node, A node.
    :param depth: int, The recursive depth.
    """
    indent = ' ' * depth

    if node.feature_index is None:
        print(f"{indent}Leaf: Class = {node.value}, Probabilities = {node.probabilities}")
    else:
        print(f"{indent}Node: X[{node.feature_index}] <= {node.threshold:.3f}?")
        print_tree(node.left, depth + 1)
        print_tree(node.right, depth + 1)

# %% [markdown]
# ### Data Loading, Training, and Evaluation

# %% [markdown]
# #### Loading the Iris dataset

# %%
iris = load_iris()
X, y = iris.data, iris.target
print("Dataset shape (features):", X.shape)
print("Dataset shape (labels):", y.shape)
# Out:
# Dataset shape (features): (150, 4)
# Dataset shape (labels): (150,)

# %% [markdown]
# #### Spliting data into training and test sets (50/50)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.50, random_state=42)
print("Training set shape:", X_train.shape)
print("Test set shape:", X_test.shape)
# Out:
# Training set shape: (75, 4)
# Test set shape: (75, 4)

# %% [markdown]
# #### Initializing and training Decision Tree classifier

# %%
clf = DecisionTreeClassifier(max_depth=4)
clf.fit(X_train, y_train)

# %% [markdown]
# #### Evaluating the model on the test set

# %%
print(f"Accuracy: {float(evaluate(clf, X_test, y_test))}")
# Out:
# Accuracy: 0.9066666666666666

# %%
print("\nDecision Tree Structure:")
print_tree(clf.tree)
# Out:
# Decision Tree Structure:
# Node: X[2] <= 1.700?
#  Leaf: Class = 0, Probabilities = [0.91666667 0.04166667 0.04166667]
#  Node: X[2] <= 5.000?
#   Node: X[3] <= 1.500?
#    Node: X[1] <= 2.200?
#     Leaf: Class = 2, Probabilities = [0.25 0.25 0.5 ]
#     Leaf: Class = 1, Probabilities = [0.03703704 0.92592593 0.03703704]
#    Node: X[1] <= 2.800?
#     Leaf: Class = 2, Probabilities = [0.16666667 0.16666667 0.66666667]
#     Leaf: Class = 1, Probabilities = [0.2 0.6 0.2]
#   Node: X[0] <= 6.000?
#    Node: X[0] <= 5.900?
#     Leaf: Class = 2, Probabilities = [0.2 0.2 0.6]
#     Leaf: Class = 1, Probabilities = [0.25 0.5  0.25]
#    Leaf: Class = 2, Probabilities = [0.04166667 0.04166667 0.91666667]

# %% [markdown]
# ### Conclusion

# %% [markdown]
# ##### Ми створили класифікатор дерева рішень і натренували його з набору даних Iris. Iris має лише 150 зразків із 4 характеристиками (features) (sepal length, sepal width, petal length, and petal width). Набір даних розділено на три класи, що відповідають трьом видам ірису (classes) (Iris setosa, Iris versicolor, Iris virginica).
# ##### З спеціальних процесів було використано: рекурсивний поділ (Recursive Partitioning), індекс gini (Gini Impurity).
# ##### Під час тренування моделі на кожній вершині алгоритм знаходить найкращу характеристику (feature index) та поріг для мінімізації індексу gini (threshold) та відповідно розділяє дані.
